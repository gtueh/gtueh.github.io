# %%
# %run sieuthi2.py
# Out:
# Tiền xử lý dữ liệu hoàn tất.
# Đã tạo xong các đặc trưng RFM:
#             Recency  Frequency  MonetaryValue
# CustomerID
# 12346           326          1       77183.60
# 12347             2          7        4310.00
# 12348            75          4        1797.24
# 12349            19          1        1757.55
# 12350           310          1         334.40
# /home/codespace/.local/lib/python3.12/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 127795 (\N{DECIDUOUS TREE}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# --- Đặc điểm trung bình của các cụm ---
#          Recency  Frequency  MonetaryValue
# Cluster
# 0          45.93       4.70        2014.42
# 1           6.73      83.60      111916.31
# 2         259.54       1.49         457.31
# /home/codespace/.local/lib/python3.12/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 128717 (\N{SHOPPING BAGS}) missing from font(s) DejaVu Sans.
# ...
